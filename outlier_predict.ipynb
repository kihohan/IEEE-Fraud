# %%
import pandas as pd
import os
from scipy import stats
from matplotlib.image import imread
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import squarify 
from matplotlib import rc
#rc('font, family = 'AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
os.chdir('/home/kiho/다운로드/유통 & 소셜 데이터')

# %%
gs = pd.read_csv("gs.csv", encoding ='CP949', parse_dates=['date.gs'])

# %%
weather = pd.read_csv("weather.csv", encoding ='CP949', parse_dates=['date.wt'])

# %%
weather_seoul = weather[weather['region_01.wt'] == '서울특별시']
weather_seoul.head(1)
# Out:
#         date.wt  region_id region_01.wt region_02.wt  temp_max  wind_max  \
# 2192 2016-01-01        108        서울특별시          종로구       4.0       3.5
#
#       temp_min  temp_avg  rhumid_avg  wa_avg  rain_sum
# 2192      -3.3       1.2        73.0     1.6       0.0

# %%
gs_seoul = gs[gs['reg_01.gs' ]== '서울특별시']
gs_seoul.head(1)
# Out:
#   reg_01.gs    date.gs gen.gs age.gs cat.gs  qty.gs reg_02.gs
# 0     서울특별시 2016-01-01      F  00~19     라면       7       종로구

# %%
figure, ((ax1,ax2,ax3,ax4,ax5,ax6), (ax7,ax8,ax9,ax10,ax11,ax12)) = plt.subplots(nrows=2, ncols=6)
figure.set_size_inches(18,8)

list_ = ['과자','라면','마스크','맥주','면도기','생리대','생수','숙취해소제','스타킹','아이스크림','우산','탄산음료']
graph_num = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12]
len_ = len (list_)
for i in range(len_):
    df = gs_seoul[gs_seoul['cat.gs'] == list_[i]]
    sns.lineplot(data = df, x = 'date.gs', y = 'qty.gs', ax = graph_num[i])
# Out:
# /home/kiho/anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
figure, ((ax1,ax2,ax3,ax4,ax5,ax6), (ax7,ax8,ax9,ax10,ax11,ax12)) = plt.subplots(nrows=2, ncols=6)
figure.set_size_inches(50,20)

list_ = ['과자','라면','마스크','맥주','면도기','생리대','생수','숙취해소제','스타킹','아이스크림','우산','탄산음료']
graph_num = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12]
len_ = len (list_)
for i in range(len_):
    sns.distplot(gs_seoul[gs_seoul['cat.gs'] == list_[i]]['qty.gs'], bins = 80, ax = graph_num[i])
